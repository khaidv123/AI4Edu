# %%
HISTORY = [
    {
        "num": "1",
        "name": "Khải",
        "utterance": "Chào mọi người, cuối tuần này chúng ta tổ chức một bữa trưa nhỏ cho nhóm được không?",
        "thoughts": [
            {
                "agent_name": "Bob",
                "inner_thought": "Khải đề xuất một hoạt động nhóm. Đây là cơ hội tốt để tăng cường gắn kết. Cần phản hồi tích cực và tham gia vào việc lên kế hoạch.",
                "stimuli": ["CON#0", "TASK#1: Lên kế hoạch bữa trưa nhóm", "THO#1"], # Added THO#1 for example
                "intrinsic_motivation": [3.8, 4.2]
            },
            {
                "agent_name": "Alice",
                "inner_thought": "Một bữa trưa nhóm! Nghe hay đấy. Mình nên nghĩ xem có gợi ý gì về địa điểm hoặc loại đồ ăn không.",
                "stimuli": ["CON#0", "TASK#1: Lên kế hoạch bữa trưa nhóm", "THO#2"], # Added THO#2
                "intrinsic_motivation": [3.9, 4.0]
            },
            {
                "agent_name": "Charlie",
                "inner_thought": "Khải muốn tổ chức ăn trưa. Cần xác định các yếu tố thực tế: thời gian, ngân sách, sở thích chung.",
                "stimuli": ["CON#0", "TASK#1: Lên kế hoạch bữa trưa nhóm", "THO#3"], # Added THO#3
                "intrinsic_motivation": [3.5, 4.1]
            }
        ]
    },
    {
        "num": "2",
        "name": "Bob",
        "utterance": "Ý kiến hay đó Khải! Mọi người có thích ăn món gì đặc biệt không?",
        "thoughts": [
            {
                "agent_name": "Alice",
                "inner_thought": "Bob hỏi về món ăn. Mình có thể đề xuất món Việt Nam, khá phổ biến và dễ chọn.",
                "stimuli": ["CON#1", "TASK#1", "THO#4"], # Adjusted THO IDs for uniqueness
                "intrinsic_motivation": [4.1, 3.9]
            },
            {
                "agent_name": "Charlie",
                "inner_thought": "Bob đang thu thập yêu cầu. Tốt. Vẫn cần làm rõ ngân sách và thời gian cụ thể.",
                "stimuli": ["CON#1", "TASK#1", "THO#5"], # Adjusted THO IDs
                "intrinsic_motivation": [3.6, 4.0]
            }
        ]
    },
    {
        "num": "3",
        "name": "Alice",
        "utterance": "Em nghĩ món Việt thì sao ạ? Dễ ăn và cũng nhiều lựa chọn.",
        "thoughts": [
            {
                "agent_name": "Bob",
                "inner_thought": "Alice đề xuất món Việt. Hợp lý. Cần xem phản ứng của Charlie và Khải.",
                "stimuli": ["CON#2", "TASK#1", "THO#6"], # Adjusted THO IDs
                "intrinsic_motivation": [3.7, 4.1]
            },
            {
                "agent_name": "Charlie",
                "inner_thought": "Món Việt là một lựa chọn an toàn. Giờ cần xem xét các quán cụ thể và giá cả.",
                "stimuli": ["CON#2", "TASK#1", "THO#7"], # Adjusted THO IDs
                "intrinsic_motivation": [3.8, 4.2]
            }
        ]
    },
    {
        "num": "4",
        "name": "Charlie",
        "utterance": "Món Việt được đó Alice. Vậy Khải ơi, ngân sách dự kiến cho bữa này khoảng bao nhiêu?",
        "thoughts": [
            {
                "agent_name": "Bob",
                "inner_thought": "Charlie đồng ý với món Việt và hỏi về ngân sách. Thông tin này rất quan trọng để chọn địa điểm.",
                "stimuli": ["CON#3", "TASK#1", "THO#8"], # Adjusted THO IDs
                "intrinsic_motivation": [3.9, 4.4]
            },
            {
                "agent_name": "Alice",
                "inner_thought": "Charlie cũng thích món Việt. Tốt! Câu hỏi về ngân sách của Charlie rất đúng lúc.",
                "stimuli": ["CON#3", "TASK#1", "THO#9"], # Adjusted THO IDs
                "intrinsic_motivation": [4.0, 4.1]
            },
        ]
    },
    {
        "num": "5",
        "name": "Khải",
        "utterance": "Okay, ngân sách tầm 250k/người nhé mọi người.",
        "thoughts": [
            {
                "agent_name": "Bob",
                "inner_thought": "Ngân sách 250k/người. Khá thoải mái cho món Việt. Có thể bắt đầu tìm các quán phù hợp gần văn phòng.",
                "stimuli": ["CON#4", "TASK#1", "THO#10"], # Adjusted THO IDs
                "intrinsic_motivation": [4.1, 4.6]
            },
            {
                "agent_name": "Alice",
                "inner_thought": "250k là mức ổn. Mình biết vài quán món Việt ngon trong tầm giá này.",
                "stimuli": ["CON#4", "TASK#1", "THO#11"], # Adjusted THO IDs
                "intrinsic_motivation": [4.3, 4.3]
            },
            {
                "agent_name": "Charlie",
                "inner_thought": "Đã có ngân sách. Giờ có thể lọc các địa điểm tiềm năng dựa trên giá cả và đánh giá.",
                "stimuli": ["CON#4", "TASK#1", "THO#12"], # Adjusted THO IDs
                "intrinsic_motivation": [4.0, 4.4]
            }
        ]
    },
    {
        "num": "6",
        "name": "Bob",
        "utterance": "Với mức đó thì khá ổn rồi. Chúng ta nên tìm quán nào gần văn phòng cho tiện di chuyển không?",
        "thoughts": [
            {
                "agent_name": "Alice",
                "inner_thought": "Gần văn phòng là hợp lý. Mình có biết quán 'Bếp Nhà' ở gần đây, giá cũng tầm đó.",
                "stimuli": ["CON#5", "TASK#1", "THO#13"], # Adjusted THO IDs
                "intrinsic_motivation": [4.1, 4.2]
            },
            {
                "agent_name": "Charlie",
                "inner_thought": "Tiêu chí vị trí rất quan trọng. Đồng ý với Bob. Cần kiểm tra các lựa chọn gần đây.",
                "stimuli": ["CON#5", "TASK#1", "THO#14"], # Adjusted THO IDs
                "intrinsic_motivation": [3.9, 4.3]
            }
        ]
    },
    {
        "num": "7",
        "name": "Alice",
        "utterance": "Em biết quán 'Bếp Nhà' ở đường X gần đây nè. Đồ ăn ổn, không gian cũng được mà giá cả phù hợp ngân sách đó.",
        "thoughts": [
            {
                "agent_name": "Bob",
                "inner_thought": "Alice đề xuất cụ thể 'Bếp Nhà'. Cần kiểm tra xem mọi người có biết quán này không hoặc tìm thêm thông tin.",
                "stimuli": ["CON#6", "TASK#1", "THO#15"], # Adjusted THO IDs
                "intrinsic_motivation": [3.8, 4.2]
            },
            {
                "agent_name": "Charlie",
                "inner_thought": "Alice có đề xuất cụ thể. Cần xác minh thông tin: menu, đánh giá, không gian có đủ chỗ cho nhóm không?",
                "stimuli": ["CON#6", "TASK#1", "THO#16"], # Adjusted THO IDs
                "intrinsic_motivation": [4.1, 4.5]
            }
        ]
    },
    {
        "num": "8",
        "name": "Charlie",
        "utterance": "À quán đó hả, mình có nghe qua. Để mình kiểm tra nhanh menu và đánh giá trên mạng xem sao.",
        "thoughts": [
            {
                "agent_name": "Bob",
                "inner_thought": "Charlie sẽ kiểm tra thông tin quán. Tốt, cần có sự xác thực trước khi quyết định.",
                "stimuli": ["CON#7", "TASK#1", "THO#17"], # Adjusted THO IDs
                "intrinsic_motivation": [3.7, 4.0]
            },
            {
                "agent_name": "Alice",
                "inner_thought": "Charlie biết quán và đang kiểm tra. Hy vọng đánh giá tốt.",
                "stimuli": ["CON#7", "TASK#1", "THO#18"], # Adjusted THO IDs
                "intrinsic_motivation": [4.0, 4.1]
            },
        ]
    },
    {
        "num": "9",
        "name": "Charlie",
        "utterance": "Mình xem rồi, quán được đánh giá khá tốt (4.3/5 sao), menu đa dạng, giá các món chính tầm 80-150k. Có vẻ ổn đấy.",
        "thoughts": [
            {
                "agent_name": "Bob",
                "inner_thought": "Thông tin Charlie cung cấp rất tích cực. Quán 'Bếp Nhà' có vẻ là lựa chọn khả thi.",
                "stimuli": ["CON#8", "TASK#1", "SUBTASK#1", "THO#19"], # Adjusted THO IDs
                "intrinsic_motivation": [4.2, 4.5]
            },
            {
                "agent_name": "Alice",
                "inner_thought": "Tuyệt, đánh giá tốt và giá cả phù hợp. Đề xuất của mình có vẻ được chấp nhận.",
                "stimuli": ["CON#8", "TASK#1", "SUBTASK#1", "THO#20"], # Adjusted THO IDs
                "intrinsic_motivation": [4.5, 4.3]
            },
        ]
    },
    {
        "num": "10",
        "name": "Khải",
        "utterance": "Tuyệt vời Charlie, cảm ơn bạn đã kiểm tra. Vậy chúng ta chốt quán 'Bếp Nhà' nhé? Ai đặt bàn được không?",
        "thoughts": [
            {
                "agent_name": "Bob",
                "inner_thought": "Khải đã đồng ý và hỏi ai sẽ đặt bàn. Mình có thể làm việc này.",
                "stimuli": ["CON#9", "TASK#1", "THO#21"], # Adjusted THO IDs
                "intrinsic_motivation": [4.3, 4.7]
            },
            {
                "agent_name": "Alice",
                "inner_thought": "Đã chốt quán. Giờ là bước đặt bàn. Bob hoặc mình có thể làm.",
                "stimuli": ["CON#9", "TASK#1", "THO#22"], # Adjusted THO IDs
                "intrinsic_motivation": [4.2, 4.2]
            },
            {
                "agent_name": "Charlie",
                "inner_thought": "Quyết định đã được đưa ra. Cần có người thực hiện việc đặt chỗ.",
                "stimuli": ["CON#9", "TASK#1", "THO#23"], # Adjusted THO IDs
                "intrinsic_motivation": [4.0, 4.3]
            }
        ]
    },
    {
        "num": "11",
        "name": "Bob",
        "utterance": "Để em đặt cho. Chúng ta đi vào trưa thứ mấy nhỉ? Khoảng 12h trưa thứ Sáu này được không?",
        "thoughts": [
            {
                "agent_name": "Alice",
                "inner_thought": "Bob nhận đặt bàn. Tốt. Thời gian thứ Sáu 12h có vẻ hợp lý với mình.",
                "stimuli": ["CON#10", "TASK#1", "THO#24"], # Adjusted THO IDs
                "intrinsic_motivation": [4.1, 4.0]
            },
            {
                "agent_name": "Charlie",
                "inner_thought": "Bob sẽ đặt bàn. Cần xác nhận thời gian: trưa thứ Sáu 12h. Cần kiểm tra lịch của mình.",
                "stimuli": ["CON#10", "TASK#1", "THO#25"], # Adjusted THO IDs
                "intrinsic_motivation": [4.2, 4.4]
            }
        ]
    },
    {
        "num": "12",
        "name": "Alice",
        "utterance": "Trưa thứ Sáu 12h em thấy ổn ạ.",
        "thoughts": [
            {
                "agent_name": "Bob",
                "inner_thought": "Alice xác nhận thời gian ổn. Cần thêm xác nhận từ Charlie và Khải.",
                "stimuli": ["CON#11", "TASK#1", "SUBTASK#2", "THO#26"], # Adjusted THO IDs
                "intrinsic_motivation": [4.4, 4.6]
            },
            {
                "agent_name": "Charlie",
                "inner_thought": "Alice đồng ý thời gian. Mình cũng thấy ổn.",
                "stimuli": ["CON#11", "TASK#1", "THO#27"], # Adjusted THO IDs
                "intrinsic_motivation": [4.0, 4.2]
            }
        ]
    },
    {
        "num": "13",
        "name": "Charlie",
        "utterance": "Mình cũng ok với trưa thứ Sáu.",
        "thoughts": [
            {
                "agent_name": "Bob",
                "inner_thought": "Charlie cũng xác nhận. Còn Khải nữa thôi là có thể tiến hành đặt bàn.",
                "stimuli": ["CON#12", "TASK#1", "SUBTASK#2", "THO#28"], # Adjusted THO IDs
                "intrinsic_motivation": [4.5, 4.7]
            },
            {
                "agent_name": "Alice",
                "inner_thought": "Charlie cũng đồng ý. Vậy là phần lớn đã ok thời gian.",
                "stimuli": ["CON#12", "TASK#1", "THO#29"], # Adjusted THO IDs
                "intrinsic_motivation": [4.1, 4.0]
            },
        ]
    },
    {
        "num": "14",
        "name": "Khải",
        "utterance": "Ok nhé Bob, vậy em đặt bàn cho 4 người, 12h trưa thứ Sáu này tại 'Bếp Nhà' nha. Cảm ơn em.",
        "thoughts": [
            {
                "agent_name": "Bob",
                "inner_thought": "Khải đã xác nhận đầy đủ thông tin: 4 người, 12h thứ Sáu, Bếp Nhà. Mình sẽ tiến hành đặt bàn ngay.",
                "stimuli": ["CON#13", "TASK#1", "SUBTASK#2", "THO#30"], # Adjusted THO IDs
                "intrinsic_motivation": [4.8, 4.9]
            },
            {
                "agent_name": "Alice",
                "inner_thought": "Khải xác nhận cuối cùng. Kế hoạch hoàn tất. Chỉ chờ Bob đặt bàn.",
                "stimuli": ["CON#13", "TASK#1", "THO#31"], # Adjusted THO IDs
                "intrinsic_motivation": [4.3, 4.2]
            },
            {
                "agent_name": "Charlie",
                "inner_thought": "Thông tin đã đầy đủ và được xác nhận bởi Khải. Bob có thể thực hiện đặt chỗ.",
                "stimuli": ["CON#13", "TASK#1", "THO#32"], # Adjusted THO IDs
                "intrinsic_motivation": [4.2, 4.4]
            }
        ]
    },
    {
        "num": "15",
        "name": "Bob",
        "utterance": "Vâng ạ, em sẽ đặt ngay và báo lại mọi người khi có xác nhận ạ.",
        "thoughts": [
            {
                "agent_name": "Alice",
                "inner_thought": "Tốt quá. Kế hoạch bữa trưa đã xong.",
                "stimuli": ["CON#14", "TASK#1", "THO#33"], # Adjusted THO IDs
                "intrinsic_motivation": [4.2, 4.1]
            },
            {
                "agent_name": "Charlie",
                "inner_thought": "Bob sẽ xử lý phần còn lại. Kế hoạch được thực hiện hiệu quả.",
                "stimuli": ["CON#14", "TASK#1", "THO#34"], # Adjusted THO IDs
                "intrinsic_motivation": [4.3, 4.3]
            }
        ]
    },

    {
        "num": "16",
        "name": "Khải",
        "utterance": "okok",
        "thoughts": [
             # No thoughts in this turn
        ]
    },

]

# %%
from typing import List, Tuple, Dict, Any

# %%
# previous_thoughts : lấy ra khoảng 3 previous

def previous_thoughts(AI_name: str, history: List[Dict[str, Any]], num: int = 3) -> Tuple[str, List[float]]:

    recent_thoughts_formatted = []
    total_internal_motivation = 0.0
    total_external_motivation = 0.0
    thoughts_found_count = 0 

    for turn in reversed(history):
        if "thoughts" in turn and isinstance(turn["thoughts"], list):
            turn_num = turn.get("num")

            if turn_num is None:
                continue

            for thought in turn["thoughts"]:
                if thoughts_found_count >= num:
                    break

                if (isinstance(thought, dict) and
                    thought.get("agent_name") == AI_name):

                    inner_thought_text = thought.get("inner_thought")
                    motivation_scores = thought.get("intrinsic_motivation")

                    if (inner_thought_text and
                        motivation_scores and
                        isinstance(motivation_scores, list) and
                        len(motivation_scores) == 2 and
                        all(isinstance(score, (int, float)) for score in motivation_scores)):

                        formatted_thought = f"(THO#{turn_num}) : {inner_thought_text}"
                        recent_thoughts_formatted.append(formatted_thought)

                        total_internal_motivation += motivation_scores[0]
                        total_external_motivation += motivation_scores[1]

                        thoughts_found_count += 1

        if thoughts_found_count >= num:
            break

    avg_internal = 0.0
    avg_external = 0.0
    if thoughts_found_count > 0:
        avg_internal = total_internal_motivation / thoughts_found_count
        avg_external = total_external_motivation / thoughts_found_count

    return "\n".join(recent_thoughts_formatted), [avg_internal, avg_external]

# %%
HISTORY = [
    {
        "num" : "1",
        "name" : "Khải",
        "utterance" : '''Cho bài toán "Xét tính đơn điệu của hàm số $f(x) = \\frac{x-1}{x+1}$.". Nào bắt đầu cùng nhau giải bài này nào.''',
        "thoughts" : []
    }
]

# %%
thoughts_str_bob, avg_motivation_bob = previous_thoughts("Bob", HISTORY, num=3)
print(thoughts_str_bob)
print(f"Average Motivation [Internal, External]: {avg_motivation_bob}")
# Out:
# Average Motivation [Internal, External]: [0.0, 0.0]

# %%
15,14,13
